# %% [markdown]
# ## Датасет собран из базы данных переписи 1994 года и содержит данные о доходах.
# ### Информация о данных:
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, * Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * salary: >50K,<=50K
#
# ## Проведите анализ данных при помощи Pandas выполнив поставленные задачи.
# ####

# %%
import pandas as pd

# %%
# загружаем датасет
data = pd.read_csv("./data/adult.data.csv")
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# **1. Посчитайте, сколько мужчин и женщин (признак *sex*) представлено в этом датасете**

# %%
def count_females_and_males(table):
    men_ammount = len(data[data["sex"]=="Male"])
    women_ammount = len(data[data["sex"]=="Female"])
    return (men_ammount, women_ammount)

ammounts = data["sex"].value_counts()
for sex in ammounts:
    print(f"sex: {sex}" )

print(count_females_and_males(data))

# %timeit count_females_and_males(data)
# %timeit data["sex"].value_counts()
# Out:
# sex: 21790
# sex: 10771
# (21790, 10771)
# 13.9 ms ± 1.63 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.36 ms ± 195 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# **2. Каков средний возраст мужчин (признак *age*) по всему датасету?**

# %%
age = data[data["sex"]=="Male"]["age"].mean()
print(f"{age:.2f}")

# %timeit data[data["sex"] == "Male"]["age"].aggregate("mean")
# %timeit data.loc[data["sex"] == "Male", "age"].mean()
# %timeit data.groupby("sex")["age"].mean()
# Out:
# 39.43
# 11.1 ms ± 6.71 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 5.02 ms ± 1.17 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.26 ms ± 947 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# **3. Какова доля граждан Соединенных Штатов (признак *native-country*)?**

# %%
print(len(data[data["native-country"]=="United-States"])/len(data)*100)

# %timeit len(data[data["native-country"] == "United-States"]) / len(data) * 100
# %timeit (data["native-country"] == "United-States").mean() * 100
# Out:
# 89.5857006848684
# 8.03 ms ± 719 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.55 ms ± 199 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# **4-5. Рассчитайте среднее значение и среднеквадратичное отклонение возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год**

# %%
result = data.groupby("salary")["age"].aggregate(["mean", "std"])

print(result)
# Out:
#              mean        std
# salary
# <=50K   36.783738  14.020088
# >50K    44.249841  10.519028

# %% [markdown]
# **6. Правда ли, что люди, которые получают больше 50k, имеют минимум высшее образование? (признак *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* или *Doctorate*)**

# %%
agr= data.groupby("salary")
print(
    data[
        data["education"].isin([
            "Bachelors",
            "Prof-school",
            "Assoc-acdm",
            "Assoc-voc",
            "Masters",
            "Doctorate"
        ])
    ].groupby("salary").size()
)
sal_50_and_more = data[data["salary"]==">50K"]
print(len(sal_50_and_more))
assert(sal_50_and_more)
# Out:
# salary
# <=50K    5981
# >50K     4535
# dtype: int64
# 7841

# %% [markdown]
# **7. Выведите статистику возраста для каждой расы (признак *race*) и каждого пола. Используйте *groupby* и *describe*. Найдите таким образом максимальный возраст мужчин расы *Asian-Pac-Islander*.**

# %%
result = data.groupby(["race", "sex"])["age"].describe()
print(result)
max_age = result.loc[("Asian-Pac-Islander", "Male"), "max"]
# Out:
#                              count       mean        std   min   25%   50%  \
# race               sex
# Amer-Indian-Eskimo Female    119.0  37.117647  13.114991  17.0  27.0  36.0
#                    Male      192.0  37.208333  12.049563  17.0  28.0  35.0
# Asian-Pac-Islander Female    346.0  35.089595  12.300845  17.0  25.0  33.0
#                    Male      693.0  39.073593  12.883944  18.0  29.0  37.0
# Black              Female   1555.0  37.854019  12.637197  17.0  28.0  37.0
#                    Male     1569.0  37.682600  12.882612  17.0  27.0  36.0
# Other              Female    109.0  31.678899  11.631599  17.0  23.0  29.0
#                    Male      162.0  34.654321  11.355531  17.0  26.0  32.0
# White              Female   8642.0  36.811618  14.329093  17.0  25.0  35.0
#                    Male    19174.0  39.652498  13.436029  17.0  29.0  38.0
#
#                              75%   max
# race               sex
# Amer-Indian-Eskimo Female  46.00  80.0
# ...

# %% [markdown]
# **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак *marital-status*)? Женатыми считаем тех, у кого *marital-status* начинается с *Married* (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
married_men = data[
    (data["sex"] == "Male") &
    (data["marital-status"].str.startswith("Married"))
]

single_men = data[
    (data["sex"] == "Male") &
    (~data["marital-status"].str.startswith("Married"))
]

married_rich_share = (married_men["salary"] == ">50K").mean() * 100
single_rich_share = (single_men["salary"] == ">50K").mean() * 100

print("Married men >50K:", married_rich_share)
print("Single men >50K:", single_rich_share)
#~isin checkнуть как отрицание типа не изин
# Out:
# Married men >50K: 44.05139945351156
# Single men >50K: 8.449509031397746

# %% [markdown]
# **9. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
max_hours = data["hours-per-week"].max()
print(max_hours)

amount_of_people = len(data.loc[data["hours-per-week"] == max_hours])
print(f"amount: {amount_of_people}")

percentage = (
    data.loc[data["hours-per-week"] == max_hours, "salary"] == ">50K"
).mean() * 100

print(percentage.round(2), "%")
# Out:
# 99
# amount: 85
# 29.41 %

# %% [markdown]
# **10. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
result = data.groupby(["salary", "native-country"])["hours-per-week"].mean()
print(result)
# Out:
# salary  native-country
# <=50K   ?                  40.164760
#         Cambodia           41.416667
#         Canada             37.914634
#         China              37.381818
#         Columbia           38.684211
#                              ...
# >50K    Thailand           58.333333
#         Trinadad&Tobago    40.000000
#         United-States      45.505369
#         Vietnam            39.200000
#         Yugoslavia         49.500000
# Name: hours-per-week, Length: 82, dtype: float64

# %% [markdown]
# **11.Сгруппируйте людей по возрастным группам *young*, *adult*, *retiree*, где:**
# * *young* соответствует 16-35 лет
# * *adult* - 35-70 лет
# * *retiree* - 70-100 лет
#
# **Проставьте название соответсвтуещей группы для каждого человека в новой колонке AgeGroup**

# %%
def age_group(age):
    if 16 <= age <= 35:
        return "young"
    elif 35 < age <= 70:
        return "adult"
    else:
        return "retiree"

data["AgeGroup"] = data["age"].apply(age_group)
result = data.groupby("AgeGroup").size()
print(result)


print(data[["age", "AgeGroup"]])
# Out:
# AgeGroup
# adult      17096
# retiree      540
# young      14925
# dtype: int64
#        age AgeGroup
# 0       39    adult
# 1       50    adult
# 2       38    adult
# 3       53    adult
# 4       28    young
# ...    ...      ...
# 32556   27    young
# 32557   40    adult
# 32558   58    adult
# 32559   22    young
# 32560   52    adult
#
# [32561 rows x 2 columns]

# %% [markdown]
# **12-13. Определите количество зарабатывающих >50K в каждой из возрастных групп (колонка AgeGroup), а также выведите название возрастной группы, в которой чаще зарабатывают больше 50К (>50K)**

# %%
result = data[data["salary"]==">50K"].groupby(["AgeGroup"]).size()

name_of_the_group = result.index[result.argmax()]
print(result)

print("AgeGroup:", name_of_the_group)
# Out:
# AgeGroup
# adult      6042
# retiree      94
# young      1705
# dtype: int64
# AgeGroup: adult

# %% [markdown]
# **14. Сгруппируйте людей по типу занятости (колонка occupation) и определите количество людей в каждой группе. После чего напишите функциюю фильтрации filter_func, которая будет возвращать только те группы, в которых средний возраст (колонка age) не больше 40 и в которых все работники отрабатывают более 5 часов в неделю (колонка hours-per-week)**

# %%
print(data.groupby("occupation").size())

def filter_func(group):
    return (group["age"].mean() <= 40) and (group["hours-per-week"] > 5).all()

result = data.groupby("occupation").filter(filter_func)

print(result)
print(result["occupation"].unique())
# Out:
# occupation
# ?                    1843
# Adm-clerical         3770
# Armed-Forces            9
# Craft-repair         4099
# Exec-managerial      4066
# Farming-fishing       994
# Handlers-cleaners    1370
# Machine-op-inspct    2002
# Other-service        3295
# Priv-house-serv       149
# Prof-specialty       4140
# Protective-serv       649
# Sales                3650
# Tech-support          928
# Transport-moving     1597
# dtype: int64
#        age    workclass  fnlwgt     education  education-num  \
# 442     24  Federal-gov  191073       HS-grad              9
# 1300    29  Federal-gov  301010  Some-college             10
# 14613   39  Federal-gov  227597       HS-grad              9
# 16111   24  Federal-gov  287988     Bachelors             13
# 18034   34  Federal-gov  172716          12th              8
# 18644   23  Federal-gov  163870  Some-college             10
# 18769   30  Federal-gov   76313       HS-grad              9
# ...
